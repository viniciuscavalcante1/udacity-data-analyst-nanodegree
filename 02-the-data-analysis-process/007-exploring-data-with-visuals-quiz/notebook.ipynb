# %%
import pandas as pd

# %matplotlib inline

pp = pd.read_csv('../powerplant_data_edited.csv')

# %%
pp.columns
# Out:
# Index(['temperature', 'exhaust_vacuum', 'ambient_pressure',
#        'relative_humidity', 'energy_output'],
#       dtype='object')

# %%
# plot relationship between temperature and electrical output
pp.plot(x='temperature', y='energy_output', kind='scatter');

# %%
# plot distribution of humidity
pp['relative_humidity'].plot(kind='hist');

# %%
# plot box plots for each variable
pp['temperature'].plot(kind='box');

# %%
pp['exhaust_vacuum'].plot(kind='box');

# %%
pp['ambient_pressure'].plot(kind='box');

# %%
pp['relative_humidity'].plot(kind='box');

# %%
pp['energy_output'].plot(kind='box');
